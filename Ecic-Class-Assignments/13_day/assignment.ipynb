# %% [markdown]
# ## **Program 1: Conditional String Manipulation**
#
# ### Description
# This program takes a string as input and performs different operations based on the length and
# properties of the string.
#
# Input:
# - A single string from the user.
#
# Processing Logic:
# - If string length \> 5:
# 	•	Condition 1:
# 	- If first half of the string equals the reverse of the second half
# 		- Output: "Palindrome Half"
# 		•	Condition 2:
# 	- Else if the string is in uppercase
# 		- Output: string with all vowels removed
# 	- Else:
# 		- Swap the first half and second half of the string
# - Else (length ≤ 5):
# 	- Print the string twice, excluding the first character

# %%
name = input("Enter your name: ")
split_word = len(name) // 2

first_half = name[:split_word]
second_half = name[split_word:]

if len(name) > 5:
    if first_half == second_half[::-1]:
        print("Palindrome Half")
    elif name.isupper():
        no_vowels = name.replace("A", "").replace("E", "").replace("I", "").replace("O", "").replace("U", "")
        print(no_vowels)
    else:
        swapped_name = second_half + first_half
        print(swapped_name)
else:
    print(name[1:] * 2)

# %% [markdown]
# ## **Program 2: Length-Based String Operations**
#
# ### Description
#
# This program processes a string based on its length and specific character patterns.
#
# Input:
# - A single string from the user.
#
# Processing Logic:
# - If length \> 6 and \< 12:
# 	•	Condition 1:
# 	- If the first and last characters are the same
# 		- Print the string excluding the first and last characters
# 		•	Condition 2:
# 	- Else if the string contains spaces
# 		- Print only the first word
# 	-	Else:
# 		- Print alternate characters using slicing
# - Else:
# 	- Print the reverse of the string

# %%
user = input("Enter a string: ")

first_half = user[:len(user) // 2]
second_half = user[len(user) // 2:]

if len(user) > 6 and len(user) < 12:
    if user[0] == user[-1]:
        print(f"User without first & last character {user[1:-1]} ")
    elif " " in user:
        print(user.split()[0])
    else:
        print(user[::2])
else:
    print(user[::-1])
# Out:
# gour

# %% [markdown]
# ## **Program 3: Consonant & Digit Based Processing**
#
# ### Description
#
# This program manipulates a string based on whether it starts with a consonant and ends with a digit.
#
# Input:
#
# A single string from the user.
#
# Processing Logic:
#
# - If string starts with a consonant:
# 	- If it ends with a digit:
# 		- Reverse only the first half of the string
# 	- Else:
# 		- Reverse only the second half of the string
# 	- Else:
# 		- Print the string without spaces
