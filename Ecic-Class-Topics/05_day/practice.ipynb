# %% [markdown]
# ## Class Practice

# %%
text = "Hello, World"
print(text[2:5])
# Out:
# llo

# %%
text = "Hello, World"
print(text[:5])
# Out:
# Hello

# %%
text = "Hello, World"
print(text[2:])
# Out:
# llo, World

# %%
text = "Hello, World"
print(text[-5:-2])

# %%
text = "Hello, World"
print(text[::2])

# %%
age = 36
text = f"My name is John, I am {age}"
print(text)

# %%
traffic_light = "Yellow"

if traffic_light == "Green":
    print("Go")
elif traffic_light == "Red":
    print("Stop")
else:
    print("Slow down")
