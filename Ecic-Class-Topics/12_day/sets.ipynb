# %%
fruit = {"apple", "banana", "cherry"}
print(fruit)

fruit.add("orange")
print(fruit)

# fruit.remove("mango")
print(fruit)

fruit.discard("mango")
print()
# Out:
# {'apple', 'banana', 'cherry'}
# {'orange', 'apple', 'banana', 'cherry'}
# {'orange', 'apple', 'banana', 'cherry'}

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

print(A | B)
print(A & B)
print(A - B)
print(A ^ B)
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}
# {1, 2, 5, 6}
