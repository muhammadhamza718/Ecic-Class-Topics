# %%
age = 18 
not_banned = True
if age >= 18 and not_banned:
    print("Eligible for license")
else:
    print("Not Enligible for License")
# Out:
# Eligible for license

# %%
password = True 
blocked = False
if password and not blocked:
    print("Login successful")
else:
    print("Not successful")
# Out:
# Login successful
