# %%
age = 18
membership_card = True

if age >= 18 and membership_card:
    print("Discount Applies")
else:
    print("Discount Not Applies")

# %%
day: str = "Sunday"
special_event: bool = False

match (day, special_event):
    case ("Sunday", False):
        print(f"Store is closed on Sunday")
    case _:
        print(f"Store is open on {day}")
# Out:
# Store is closed on Sunday
