# %%
# age = int(input("Enter your age: "))

# if age < 18 or age > 60:
#     print("Eligible for a discount")
# else:
#     print("Not eligible for a discount")
# Out:
# Eligible for a discount

# %%
# age = int(input("Enter your age: "))
# is_student = True

# if age <= 25 and is_student:
#     print("Eligible for scholarship")
# else:
#     print("Not eligible for scholarship")
# Out:
# Eligible for scholarship

# %%
# username = input("Enter your username: ")
# password = 1234


# if username == "admin" and password == 1234:
#     print("Access granted!")
# else:
#     print("Access denied!")
# Out:
# Access denied!

# %%
temp = int(input("Enter the temperature: "))

if temp <= 0 and not temp >= 40:
    print("Extreme Cold")
else:
    print("Extreme Heaten")
# Out:
# Extreme Heaten

# %%
marks = 45

if marks >= 50 and marks <= 100:
    print("Inclusive")
else:
    print("Exclusive")
# Out:
# Exclusive

# %%
day = "Monday"
is_holiday = True

if day == "Sunday" or is_holiday:
    print("Rest day")
else:
    print("Working day")

# %%
age = int(input("Enter your age: "))

if age < 18:
    print("Minor")
else:
    print("Adult")

# %%
has_ticket = True
has_id = True

if has_ticket and has_id:
    print("Entry Allow")
else:
    print("Entry not allow")
# Out:
# Entry Allow

# %%
salary = int(input("Enter your salary: "))
year_of_experience = int(input("Enter your experience: "))

if salary >= 50000 and year_of_experience >= 2:
    print("Loan accepted")
else:
    print("Loan not accepted")
# Out:
# Loan not accepted

# %%
login_attempt = 2
is_verified = False

if login_attempt < 3 and is_verified:
    print("Login successful")
else:
    print("Login Failed")
# Out:
# Login Failed

# %%
# age = 18
# is_citizen = True

# if age <= 18 and is_citizen:
#     print("Voting Is Allowed")
# else:
#     print("Voting is not Allowed")

# %%
email = input("Enter your email: ")
password = input("Enter your password: ")

if email == "demo@gmail.com" and not password == "":
    print("Login successful")
else:
    print("Login failed!")
# Out:
# Login failed!

# %%
age = 20
is_citizen = True

if age >= 18 and is_citizen:
    print("Login successful")
else:
    print("Login Failed!")
# Out:
# Login successful
