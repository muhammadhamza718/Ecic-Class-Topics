# %%
list = []

number1 = int(input("Enter your first number: "))
number2 = int(input("Enter your second number: "))
number3 = int(input("Enter your third number: "))
number4 = int(input("Enter your fourth number: "))
number5 = int(input("Enter your fifth number: "))

full_list = [number1 , number2, number3, number4, number5]
list.append(full_list)


if list[0] > list[-1]:
    print(list[0][2])
else:
    print(list[0][0:-1])
# Out:
# [3, 6, 4, 8]

# %%
number1 = int(input("Enter your first number: "))
number2 = int(input("Enter your second number: "))
number3 = int(input("Enter your third number: "))
number4 = int(input("Enter your fourth number: "))

full_list = [number1 , number2, number3, number4]
list.append(full_list)
# print(len(full_list))

if len(full_list) % 2 == 0:
    print(full_list) 
    if full_list[0] % 2 == 0:
        print(full_list[-2:])
    else:
        print(full_list[-1:2])

# %%
number1 = int(input("Enter your first number: "))
number2 = int(input("Enter your second number: "))
number3 = int(input("Enter your third number: "))
number4 = int(input("Enter your fourth number: "))
number5 = int(input("Enter your fifth number: "))
number6 = int(input("Enter your sixth number: "))

full_list = [number1 , number2, number3, number4, number5, number6]

if full_list[2:4] == full_list[2:4]:
    print()
