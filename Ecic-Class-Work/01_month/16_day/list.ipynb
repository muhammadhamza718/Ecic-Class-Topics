# %% [markdown]
# ## List
#
# - Collection of items that is ordered a mutable allows duplicate values also can store multiple data types.
#
# ### Examples:

# %%
number = [10, 20, 30, 40]
names = ["Alice", "Bob", "Charlie", "David"]
mixed = [1, "Hello", 3.14, True]

# %% [markdown]
# Creating a list:

# %%
my_list = []
my_list = [1, 2, 3]
my_list = list[(1, "Hello", 3.14, True)]

# %% [markdown]
# ### Indexing in list:
#
# - Index start with 0
# - Negative start with 1

# %%
Fruit = ["Mango", "Banana", "Orange", "Grapes"]

print(Fruit[0])
# Out:
# Mango

# %% [markdown]
# #### syntax of list:
#
# list[start, end, steps]

# %% [markdown]
# ### List functions:
#
# - len() length of list
# - max() maximum of list
# - min() minimum of list
# - sum() sum of list
# - count() count the list
# - index() index of list
# - sort() sort the list
# - reverse() reverse the list
# - copy() copy list
