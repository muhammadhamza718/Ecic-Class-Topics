# %%
i = 1

while i <= 5:
    if i == 5:
        break
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4

# %%
num = 12345
original = num
reverse = 0

while num > 0:
    digit = num % 10
    reverse = reverse * 10 + digit
    num = num // 10

print(reverse)
# Out:
# 54321
