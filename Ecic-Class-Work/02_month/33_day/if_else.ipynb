# %% [markdown]
# ### **📌 Topic 1:**  `if / else`
#
# **Core mindset:** An if/else is a decision gate. Your program hits a fork in the road and must choose a path based on a condition that is either `True` or `False`.
#
# **Example:**
#
# ```
# if condition:
#     # path A
# else:
#     # path B
# ```

# %% [markdown]
# ### **✅ 10 Basic Questions**
#
# **Q1.** Write a program that takes a number and prints `"Positive"` if it's greater than 0, otherwise prints `"Non-positive"`.

# %%
number = int(input("Enter your number: "))

if number > 0:
    print("Positive")
else:
    print("Non-Positive")
# Out:
# Non-Positive

# %% [markdown]
# **Q2.** A store gives a 10% discount if the total bill is above ₹500. Write a program that takes the bill amount and prints the final amount to pay.

# %%
bill = int(input("Enter your number: "))

if bill > 500:
    discount = bill * 0.10
    total_amount = bill - discount
else:
    total_amount = bill

print(f"Final amount to pay: ₹{total_amount:.2f}")
# Out:
# Final amount to pay: ₹540.00

# %% [markdown]
# **Q3.** Write a program that checks if a person is eligible to vote. (Age must be 18 or above.)

# %%
age = 18

if age >= 18:
    print("Eligible for voting!")
else:
    print("Not eligible for voting!")
# Out:
# Eligible for voting!

# %% [markdown]
# **Q4.** You have a variable `is_raining = True`. Print `"Take an umbrella"` if it's raining, otherwise print `"Enjoy the weather"`.

# %%
is_raining = True 

if is_raining:
    print("Take an umbrella")
else:
    print("Enjoy the weather")
# Out:
# Take an umbrella

# %% [markdown]
# **Q5.** Write a program that takes two numbers and prints which one is larger. If they're equal, print `"Both are equal"`.

# %%
number_1 = int(input("Enter your first number: "))
number_2 = int(input("Enter your second number: "))

if number_1 > number_2:
    print(f"first number is greater than second number: {number_1} > {number_2}")
elif number_2 > number_1:
    print(f"second number is greater than first number: {number_2} > {number_1}")
else: 
    print(f"Both first/second number are equal: {number_1} = {number_2}")
# Out:
# second number is greater than first number: 8 > 6

# %% [markdown]
# **Q6.** A user enters a password. If it matches `"secret123"`, print `"Access granted"`, otherwise print `"Access denied"`.

# %%
password = input("Enter your password: ").strip().lower()

if password == "secret123":
    print("Access granted!")
else:
    print("Access denied!")
# Out:
# Access granted!

# %% [markdown]
# **Q7.** Write a program that takes a number and checks if it's even or odd. (Hint: use `%`)

# %%
number = int(input("Enter your number: "))

if number % 2 == 0:
    print(f"The number is odd: {number}")
else:
    print(f"The number is even: {number}")

# %% [markdown]
# **Q8.** A student passes if their marks are 40 or above. Write a program that prints `"Pass"` or `"Fail"` based on input marks.

# %%
marks = 59

if marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %% [markdown]
# **Q9.** Write a program that checks if a given year is a leap year. A year is a leap year if it's divisible by 4. (Just use divisibility by 4 for now.)

# %%
year = int(input("Enter a year: "))

if year % 4 == 0:
    print("It is a leap year.")
else:
    print("It is not a leap year.")
# Out:
# It is a leap year.

# %% [markdown]
# **Q10.** You're building a simple ATM. The user wants to withdraw ₹2000. The account balance is ₹1500. Print whether the transaction is `"Approved"` or `"Declined"`.

# %%
balance = 1500

if 2000 > balance:
    print("Declined")
else:
    print("Approved")
# Out:
# Declined
