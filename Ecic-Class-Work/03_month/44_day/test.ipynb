# %% [markdown]
# Assign a variable s & t as "Favo" & "rite". Concentate the s & t & print them

# %%
s = "Favo"
t = "rite"

sum = s + t
print(sum)
# Out:
# Favorite

# %%
score = 56 

if score > 50: 
    print("You passed the exam!")
else: 
    print("you are failed")
# Out:
# You passed the exam

# %%
score = 56

if score > 50: 
    print("You passed the exam!")
elif score > 40 and score < 50:  
    print("You are failed but keep trying!")
else: 
    print("You are failed!")
# Out:
# You are failed!

# %%
score = 56

if score > 50: 
    print("You loss")
else: 
    print("You win")
# Out:
# You win

# %%
fruit_basket = ["apple", "banana", "cherry"]

print(fruit_basket[1])
# Out:
# banana

# %%
fruit_basket = ("apple", "banana", "cherry", "kiwi", "melon", "mango")

print(fruit_basket[-1])
# Out:
# mango

# %%
for i in range(2, 16, 3):
    print(f"{i}^2 = {i ** 2}")
# Out:
# 2^2 = 4
# 5^2 = 25
# 8^2 = 64
# 11^2 = 121
# 14^2 = 196
