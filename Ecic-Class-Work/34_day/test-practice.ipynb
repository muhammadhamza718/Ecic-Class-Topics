# %%
num = []

while True:
    number = int(input("Enter your number: "))
    if number < 0:
        break
    num.append(number)
    total = sum(num)
    
print(total)
# Out:
# 380

# %%
total_name = []

while True:
    name = input("Enter your name: ")
    if name == "END":
        break
    total_name.append(name)

print(f"I am done: {total_name}")
# Out:
# I am done: ['hamza', 'adil', 'khurram', 'khubaib', 'arsalan']

# %%
i = 0
total_grade = 0

while True:
    grade = float(input("Enter your grade: "))

    if grade < 0:
        break

    total_grade += grade
    i = i + 1

if i == 0:
    print("No grades entered")
else:
    average = total_grade / i
    print("Average:", average)

    if average < 40:
        print("Your grade is E")
    elif average <= 49:
        print("Your grade is F")
    elif average <= 59:
        print("Your grade is C")
    elif average <= 69:
        print("Your grade is B")
    elif average <= 79:
        print("Your grade is A")
    else:
        print("Your grade is A+")
# Out:
# 480.0
# Your grade is B

# %%
import random

print("""
There are 7 sticks
You can pick 1, 2, or 3 sticks
The player who picks the last stick loses
""")

while True:
    user_choice = int(input("Enter your choice (1/2/3): "))
    computer_choice = random.choice([1, 2, 3])

    sticks = 7
